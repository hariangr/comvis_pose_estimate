# %%
import pandas as pd

from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
from const import id_name
import numpy as np

# %%
path_a = "leia.csv"
df_a = pd.read_csv(path_a).iloc[:200]
df_a
# Out:
#      frame_no  xnose  ynose  xleft_eye_inner  yleft_eye_inner  xleft_eye  \
# 0           0    590    213              591              205        593
# 1           1    590    213              591              205        593
# 2           2    590    213              591              205        593
# 3           3    590    213              591              205        593
# 4           4    590    213              591              205        593
# ..        ...    ...    ...              ...              ...        ...
# 195       195    563    209              568              201        572
# 196       196    563    213              568              204        572
# 197       197    563    217              568              208        571
# 198       198    562    221              567              214        571
# 199       199    562    229              567              221        571
#
#      yleft_eye  xleft_eye_outer  yleft_eye_outer  xright_eye_inner  ...  \
# 0          206              595              206               583  ...
# 1          206              595              206               583  ...
# 2          206              595              206               583  ...
# 3          206              594              206               583  ...
# 4          206              594              206               583  ...
# ..         ...              ...              ...               ...  ...
# 195        200              576              200               560  ...
# 196        204              576              203               559  ...
# 197        208              575              207               559  ...
# 198        213              575              213               559  ...
# 199        220              575              220               559  ...
#
#      xright_ankle  yright_ankle  xleft_heel  yleft_heel  xright_heel  \
# 0             573           559         554         586          555
# 1             573           559         554         591          555
# 2             573           559         554         595          555
# 3             573           559         553         596          555
# 4             573           559         553         595          555
# ..            ...           ...         ...         ...          ...
# 195           562           585         588         598          562
# 196           562           585         586         599          561
# 197           561           585         586         599          561
# 198           561           585         585         599          560
# 199           561           586         584         602          560
#
#      yright_heel  xleft_foot_index  yleft_foot_index  xright_foot_index  \
# 0            566               588               613                584
# 1            566               588               613                583
# 2            566               589               613                583
# 3            566               589               613                583
# 4            567               589               613                583
# ..           ...               ...               ...                ...
# 195          597               589               615                568
# 196          597               590               615                568
# 197          596               590               615                569
# 198          599               594               615                573
# 199          599               594               615                572
#
#      yright_foot_index
# 0                  606
# 1                  603
# 2                  601
# 3                  601
# 4                  600
# ..                 ...
# 195                612
# 196                612
# 197                612
# 198                612
# 199                612
#
# [200 rows x 67 columns]

# %%
path_b = "a.csv"
df_b = pd.read_csv(path_b)[:200]
df_b
# Out:
#      frame_no  xnose  ynose  xleft_eye_inner  yleft_eye_inner  xleft_eye  \
# 0           0    336    106              339              102        341
# 1           1    337    106              340              102        342
# 2           2    338    107              341              102        343
# 3           3    339    107              342              102        343
# 4           4    339    107              342              103        343
# ..        ...    ...    ...              ...              ...        ...
# 195       195    344     97              347               93        349
# 196       196    345     96              348               92        350
# 197       197    346     96              349               93        351
# 198       198    347     98              350               94        352
# 199       199    348    101              351               97        352
#
#      yleft_eye  xleft_eye_outer  yleft_eye_outer  xright_eye_inner  ...  \
# 0          102              343              102               334  ...
# 1          102              343              102               335  ...
# 2          102              344              102               336  ...
# 3          102              345              102               337  ...
# 4          102              345              102               337  ...
# ..         ...              ...              ...               ...  ...
# 195         93              351               93               342  ...
# 196         93              352               93               343  ...
# 197         93              352               93               344  ...
# 198         94              353               94               345  ...
# 199         97              354               97               345  ...
#
#      xright_ankle  yright_ankle  xleft_heel  yleft_heel  xright_heel  \
# 0             334           291         354         298          338
# 1             337           291         354         298          340
# 2             339           291         354         299          343
# 3             340           292         354         299          344
# 4             341           293         354         299          344
# ..            ...           ...         ...         ...          ...
# 195           288           245         360         288          293
# 196           290           236         359         288          296
# 197           293           226         358         288          299
# 198           296           217         358         288          303
# 199           299           212         357         286          307
#
#      yright_heel  xleft_foot_index  yleft_foot_index  xright_foot_index  \
# 0            295               352               309                333
# 1            295               352               310                336
# 2            295               353               310                337
# 3            297               353               310                337
# 4            298               353               311                337
# ..           ...               ...               ...                ...
# 195          249               370               297                275
# 196          240               369               297                276
# 197          230               369               297                278
# 198          223               369               297                281
# 199          217               368               297                283
#
#      yright_foot_index
# 0                  311
# 1                  311
# 2                  309
# 3                  309
# 4                  309
# ..                 ...
# 195                266
# 196                254
# 197                243
# 198                234
# 199                231
#
# [200 rows x 67 columns]

# %%
col = 32
distance, path = fastdtw(df_a[df_a.columns[col]], df_b[df_b.columns[col]], dist=euclidean)
distance
# Out:
# 16983.0

# %%
import numpy as np
total = 0
for col in df_a.columns[1:]: # Skip kolom frame_no
    a1 = df_a[col]
    a2 = df_b[col]
    corr = np.corrcoef(a1,a2)
    total += corr

total[0][1] / len(df_a.columns[1:])
# Out:
# -0.06181752095512788
